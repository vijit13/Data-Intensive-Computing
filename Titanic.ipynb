# %%
sourceUrl <- "https://www.kaggle.com/c/titanic-gettingStarted/download/train.csv"
if(!file.exists("rawdata")){dir.create("rawdata")}
fileName <- "rawdata/train.csv"
if(!file.exists(fileName))   {  
    download.file(sourceUrl, destfile = fileName, method="curl")  
}

sourceUrl <- "https://www.kaggle.com/c/titanic-gettingStarted/download/test.csv"
if(!file.exists("rawdata")){dir.create("rawdata")}
fileName <- "rawdata/test.csv"
if(!file.exists(fileName))   {  
    download.file(sourceUrl, destfile = fileName, method="curl")  
}

# %%
train <- read.csv("train.csv", header=TRUE)
test <- read.csv("test.csv", header=TRUE)

# %%
test
# Out:
#     PassengerId Pclass
# 1   892         3
# 2   893         3
# 3   894         2
# 4   895         3
# 5   896         3
# 6   897         3
# 7   898         3
# 8   899         2
# 9   900         3
# 10  901         3
# 11  902         3
# 12  903         1
# 13  904         1
# 14  905         2
# 15  906         1
# 16  907         2
# 17  908         2
# 18  909         3
# 19  910         3
# 20  911         3
# 21  912         1
# 22  913         3
# 23  914         1
# 24  915         1
# 25  916         1
# 26  917         3
# 27  918         1
# 28  919         3
# 29  920         1
# 30  921         3
# ⋮   ⋮           ⋮
# 389 1280        3
# 390 1281        3
# 391 1282        1
# 392 1283        1
# 393 1284        3
# 394 1285        2
# 395 1286        3
# 396 1287        1
# 397 1288        3
# 398 1289        1
# 399 1290        3
# 400 1291        3
# 401 1292        1
# 402 1293        2
# 403 1294        1
# 404 1295        1
# 405 1296        1
# ...

# %%
nrow(train)
# Out:
# [1] 891

# %%
train <- within(train, Survived <- factor(Survived, labels = c("No", "Yes")))
train <- within(train, Pclass <- factor(Pclass))
test <- within(test, Pclass <- factor(Pclass))

# %%
train
# Out:
#     PassengerId Survived Pclass
# 1    1          No       3
# 2    2          Yes      1
# 3    3          Yes      3
# 4    4          Yes      1
# 5    5          No       3
# 6    6          No       3
# 7    7          No       1
# 8    8          No       3
# 9    9          Yes      3
# 10  10          Yes      2
# 11  11          Yes      3
# 12  12          Yes      1
# 13  13          No       3
# 14  14          No       3
# 15  15          No       3
# 16  16          Yes      2
# 17  17          No       3
# 18  18          Yes      2
# 19  19          No       3
# 20  20          Yes      3
# 21  21          No       2
# 22  22          Yes      2
# 23  23          Yes      3
# 24  24          Yes      1
# 25  25          No       3
# 26  26          Yes      3
# 27  27          No       3
# 28  28          No       1
# 29  29          Yes      3
# 30  30          No       3
# ⋮   ⋮           ⋮        ⋮
# 862 862         No       2
# 863 863         Yes      1
# ...

# %%
library(ggplot2)

# %%
qplot(Sex, Pclass, colour = Survived, data=train, geom="jitter")
qplot(Survived, data=train, geom="bar",facets = . ~ Sex, fill=Pclass)
qplot(Age, data=train, geom="bar",facets = . ~ Survived, fill=Pclass)
qplot(SibSp, data=train, geom="bar",facets = . ~ Survived, fill=Pclass)
# Out:
# plot without title
# Warning message:
# “Removed 177 rows containing non-finite values (stat_count).”Warning message:
# “position_stack requires non-overlapping x intervals”
# plot without title
# plot without title
# plot without title

# %%
install.packages("randomForest")
# Out:
# Installing package into ‘/home/vijit/R/x86_64-pc-linux-gnu-library/3.3’
# (as ‘lib’ is unspecified)

# %%
library(randomForest)
# Out:
# randomForest 4.6-12
# Type rfNews() to see new features/changes/bug fixes.
#
# Attaching package: ‘randomForest’
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin

# %%
fit <- randomForest(Survived ~Pclass + Sex, data=train)
prediction.1 <- predict(fit, test)

# %%
summary(train)
# Out:
#   PassengerId    Survived  Pclass                                     Name
#  Min.   :  1.0   No :549   1:216   Abbing, Mr. Anthony                  :  1
#  1st Qu.:223.5   Yes:342   2:184   Abbott, Mr. Rossmore Edward          :  1
#  Median :446.0             3:491   Abbott, Mrs. Stanton (Rosa Hunt)     :  1
#  Mean   :446.0                     Abelson, Mr. Samuel                  :  1
#  3rd Qu.:668.5                     Abelson, Mrs. Samuel (Hannah Wizosky):  1
#  Max.   :891.0                     Adahl, Mr. Mauritz Nils Martin       :  1
#                                    (Other)                              :885
#      Sex           Age            SibSp           Parch             Ticket
#  female:314   Min.   : 0.42   Min.   :0.000   Min.   :0.0000   1601    :  7
#  male  :577   1st Qu.:20.12   1st Qu.:0.000   1st Qu.:0.0000   347082  :  7
#               Median :28.00   Median :0.000   Median :0.0000   CA. 2343:  7
# ...
